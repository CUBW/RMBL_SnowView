# %%
import rasterio
import numpy as np
import os
import glob
import cv2
import matplotlib.pyplot as plt

from tqdm import tqdm
from rasterio.warp import Resampling
from rasterio import windows
from itertools import product
from rasterio.windows import from_bounds

SOURCE = 'C:/Users/apfox/UCB-O365/Travis Hainsworth - RMBL/2 - Source Data/2019-2020_Data'
output_filepath = 'outputs/'
bad_files = [
        "VirginiaBasin_2019_07_10_snow.tif",
        "VirginiaBasin_2019_07_17_snow.tif",
        "VirginiaBasin_2019_07_24_snow.tif",
        "VirginiaBasin_2019_07_30_snow.tif",
        "VirginiaBasin_2020_08_01_snow.tif",
        "VirginiaBasin_2020_08_08_snow.tif",
        "ParadiseBasin_2020_06_12_snow.tif",
        "ParadiseBasin_2019_08_02_snow.tif",
        "EastRiverTrail_2020_05_26_snow.tif",
        "DeerCreekTrail_2019_05_11_snow.tif",
        "EastRiverTrail_2020_05_05_snow.tif",
        "SouthBaldy_2019_08_02_snow.tif", # errors start here
        "StrandHill_2019_05_16_snow.tif",
        "VirginiaBasin_2020_06_22_snow.tif"
        ]

def get_filename(location, date):
    """
    Generate the filenames for the snow and binary snow images.

    Args:
        location (str): The location of the image.
        date (str): The date of the image.

    Returns:
        tuple: A tuple containing the filenames for the snow and binary snow images.
    """
    return (f"{location}_{date}_snow.tif", f"{location}_{date}_snowbinary.tif")

# %%
def resample(source, target_meta):
    """
    Resamples the source data to match the size and projection of the target data.

    Parameters:
        source (rasterio.DatasetReader): The source dataset to be resampled.
        target (rasterio.DatasetReader): The target metadata with the desired size and projection.

    Returns:
        numpy.ndarray: The resampled data with the same number of channels as the source dataset.

    """
    resampled_data = np.empty((source.count, target_meta['height'], target_meta['width']), dtype=np.float32)
    for i in range(source.count):  # Loop over channels
        rasterio.warp.reproject(
            source=source.read(i + 1),
            destination=resampled_data[i],
            src_transform=source.transform,
            src_crs=source.crs,
            dst_transform=target_meta['transform'],
            dst_crs=target_meta['crs'],
            resampling=Resampling.cubic_spline       
        )
    return resampled_data

# %%
def trim_larger_to_smaller(large_src, small_src):
    """
    Trim the larger raster image to the bounds of the smaller raster image.

    Parameters:
        large_src (rasterio.io.DatasetReader): An already opened rasterio dataset for the larger image.
        small_src (rasterio.io.DatasetReader): An already opened rasterio dataset for the smaller image.

    Returns:
        trimmed_data (numpy.ndarray): The trimmed data from the larger image.
        trimmed_meta (dict): The updated metadata for the trimmed GeoTIFF.
    """
    
    # Read metadata and bounds of the smaller image
    small_bounds = small_src.bounds

    # Calculate the window to read from the larger GeoTIFF
    window = from_bounds(
        small_bounds.left, small_bounds.bottom,
        small_bounds.right, small_bounds.top,
        transform=large_src.transform
    )

    # Read the data from the larger GeoTIFF using the calculated window
    trimmed_data = large_src.read(window=window)

    # Update metadata for the trimmed GeoTIFF
    trimmed_meta = large_src.meta.copy()
    trimmed_meta.update({
        "height": round(window.height),
        "width": round(window.width),
        "transform": rasterio.windows.transform(window, large_src.transform)
    })

    return trimmed_data, trimmed_meta

# %%
# get all tif files from Imagery
lfp = os.path.join(SOURCE, "Imagery")
tif_files = glob.glob(os.path.join(lfp, '**/*.tif'), recursive=True)

# %%
def trim_and_resample(snow_path, mask_path, num_channels = 3):
    #open the images for the selected location and date
    snow_og_src = rasterio.open(snow_path)
    snow_meta = snow_og_src.meta

    snowbinary_og_src = rasterio.open(mask_path)
    snowbinary_meta = snowbinary_og_src.meta

    # trim bigger image to match smaller image with raster windows
    trimmed_snow_image, trimmed_snow_meta = trim_larger_to_smaller(snow_og_src, snowbinary_og_src)

    # resample mask to match snow image
    resampled_snowbinary = resample(snowbinary_og_src, trimmed_snow_meta)

    # create shape of mask
    shape = resampled_snowbinary >= 0 

    # trim snow image to match mask shape
    trimmed_snow_image = np.where(shape, trimmed_snow_image, 0)

    # add 4th alpha channel
    if num_channels == 4:
        alpha = np.where(shape, 255, 0)
        trimmed_snow_image = np.append(trimmed_snow_image, alpha, axis=0)
        trimmed_snow_meta['count'] = 4

    return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta

# %%
def pad_for_tiles(img, mask, meta, tilesize=512):
    """
    Pad the image and mask to be divisible by the tilesize.

    Parameters:
        img (numpy.ndarray): The image to be padded.
        mask (numpy.ndarray): The mask to be padded.
        meta (dict): The metadata for the image and mask.
        tilesize (int): The size of the tiles to be generated.

    Returns:
        img (numpy.ndarray): The padded image.
        mask (numpy.ndarray): The padded mask.
        meta (dict): The updated metadata for the padded image and mask.
    """
    # Calculate the padding required to make the image dimensions divisible by the tilesize
    pad_h = tilesize - (img.shape[1] % tilesize)
    pad_w = tilesize - (img.shape[2] % tilesize)

    # Pad the image and mask
    img = np.pad(img, ((0, 0), (0, pad_h), (0, pad_w)), mode='constant', constant_values=0)
    mask = np.pad(mask, ((0,0), (0, pad_h), (0, pad_w)), mode='constant', constant_values=0)

    # Update metadata for the padded image
    meta.update({
        "height": img.shape[1],
        "width": img.shape[2],
        "transform": rasterio.windows.transform(rasterio.windows.Window(0, 0, img.shape[2], img.shape[1]), meta['transform'])
    })

    return img, mask, meta

# %%
def tile_windows(meta, tilesize):
    ncols, nrows = meta['width'], meta['height']
    offsets = product(range(0, ncols, tilesize), range(0, nrows, tilesize))
    big_window = windows.Window(col_off=0, row_off=0, width=ncols, height=nrows)
    for col_off, row_off in offsets:
        window = windows.Window(col_off=col_off, row_off=row_off, width=tilesize, height=tilesize).intersection(big_window)
        yield window

def generate_tiles(image, mask, meta, tilesize = 512):
    image_tiles = []
    mask_tiles = []
    for window in tile_windows(meta, tilesize):

        image_window = image[:, window.row_off:window.row_off + window.height, window.col_off:window.col_off + window.width]
        mask_window = mask[:, window.row_off:window.row_off + window.height, window.col_off:window.col_off + window.width]

        # if image is 50% empty, skip
        if np.count_nonzero(image_window) < (0.5 * image_window.size):
            continue

        image_tiles.append(image_window)
        mask_tiles.append(mask_window)

    return image_tiles, mask_tiles

# %%
def store_tiles(image_tiles, mask_tiles, output_dir, location, date):
    np.savez_compressed(os.path.join(output_dir, f"{location}_{date}_tiles_images.npz"), *image_tiles)
    np.savez_compressed(os.path.join(output_dir, f"{location}_{date}_tiles_masks.npz"), *mask_tiles)

# %%
import math
def display_tiles(tiles):
    
    fig, axs = plt.subplots(53, 42)
    for i, ax in enumerate(axs.flat):
        ax.imshow(tiles[i][0], cmap='gray')
        ax.axis('off')
    plt.show()

# %%
def process_file(file_path):
    #get filename
    filename = os.path.basename(file_path)
    tags = filename.split('_')

    #exctract location from filename
    location = tags[0]

    #extract date from filename
    date = f'{tags[1]}_{tags[2]}_{tags[3]}'

    #Skip bad files
    if f'{location}_{date}_snow.tif' in bad_files:
        return

    snow, mask, snow_meta = trim_and_resample(
        os.path.join(SOURCE, 'Imagery', location, f'{location}_{date}_snow.tif'), 
        os.path.join(SOURCE, 'Snow_Mask', location, f'{location}_{date}_snowbinary.tif')
    )

    snow, mask, snow_meta = pad_for_tiles(snow, mask, snow_meta)

    snow_tiles, mask_tiles = generate_tiles(snow, mask, snow_meta)

    store_tiles(snow_tiles, mask_tiles, output_filepath, location, date)

# %%
from concurrent.futures import ThreadPoolExecutor

# parallelization

num_threads = 10

with ThreadPoolExecutor(num_threads) as executor:    
    list(tqdm(executor.map(process_file, tif_files), total=len(tif_files)-len(bad_files), unit='images'))
# Out:
#   0%|          | 0/131 [00:00<?, ?images/s]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#   2%|▏         | 2/131 [07:57<8:32:57, 238.58s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#   9%|▉         | 12/131 [09:23<1:13:05, 36.85s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  19%|█▉        | 25/131 [12:17<26:39, 15.09s/images]  C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  20%|█▉        | 26/131 [12:51<29:10, 16.67s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  26%|██▌       | 34/131 [14:15<22:23, 13.85s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  34%|███▎      | 44/131 [15:12<11:40,  8.05s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  40%|███▉      | 52/131 [17:39<16:01, 12.17s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  44%|████▍     | 58/131 [19:40<20:24, 16.77s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  46%|████▌     | 60/131 [19:59<17:24, 14.71s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  48%|████▊     | 63/131 [22:17<28:37, 25.26s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  52%|█████▏    | 68/131 [24:19<26:00, 24.77s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  54%|█████▍    | 71/131 [25:28<24:02, 24.04s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  56%|█████▌    | 73/131 [26:30<24:44, 25.59s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  61%|██████    | 80/131 [27:31<11:43, 13.79s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  62%|██████▏   | 81/131 [27:45<11:34, 13.88s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  63%|██████▎   | 83/131 [29:38<20:50, 26.06s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  66%|██████▋   | 87/131 [30:37<14:36, 19.91s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  72%|███████▏  | 94/131 [31:17<06:47, 11.02s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  76%|███████▋  | 100/131 [31:59<04:05,  7.91s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  78%|███████▊  | 102/131 [33:49<10:34, 21.87s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  80%|████████  | 105/131 [34:06<06:11, 14.27s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  86%|████████▋ | 113/131 [36:37<05:50, 19.45s/images]
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 8
#       5 num_threads = 10
#       7 with ThreadPoolExecutor(num_threads) as executor:
# ----> 8     list(tqdm(executor.map(process_file, tif_files), total=len(tif_files)-len(bad_files), unit='images'))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# Cell In[10], line 16, in process_file(file_path)
#      13 if f'{location}_{date}_snow.tif' in bad_files:
#      14     return
# ---> 16 snow, mask, snow_meta = trim_and_resample(
#      17     os.path.join(SOURCE, 'Imagery', location, f'{location}_{date}_snow.tif'),
#      18     os.path.join(SOURCE, 'Snow_Mask', location, f'{location}_{date}_snowbinary.tif')
#      19 )
#      21 snow, mask, snow_meta = pad_for_tiles(snow, mask, snow_meta)
#      23 snow_tiles, mask_tiles = generate_tiles(snow, mask, snow_meta)
#
# Cell In[5], line 19, in trim_and_resample(snow_path, mask_path, num_channels)
#      16 shape = resampled_snowbinary >= 0
#      18 # trim snow image to match mask shape
# ---> 19 trimmed_snow_image = np.where(shape, trimmed_snow_image, 0)
#      21 # add 4th alpha channel
#      22 if num_channels == 4:
#
# File <__array_function__ internals>:200, in where(*args, **kwargs)
#
# ValueError: operands could not be broadcast together with shapes (1,19467,21667) (3,19345,21667) ()

# %%
# get list of all files in output directory
output_files = glob.glob(os.path.join(output_filepath, '*.npz'))

# break into location and date
completed_files = set()
for file in output_files:
    filename = os.path.basename(file)
    tags = filename.split('_')
    completed_files.add((tags[0], f'{tags[1]}_{tags[2]}_{tags[3]}'))

completed_files
# Out:
# {('DeerCreekTrail', '2019_05_22'),
#  ('DeerCreekTrail', '2019_05_30'),
#  ('DeerCreekTrail', '2019_06_07'),
#  ('DeerCreekTrail', '2019_06_13'),
#  ('DeerCreekTrail', '2019_06_19'),
#  ('DeerCreekTrail', '2019_07_02'),
#  ('DeerCreekTrail', '2020_05_05'),
#  ('DeerCreekTrail', '2020_05_12'),
#  ('DeerCreekTrail', '2020_05_23'),
#  ('DeerCreekTrail', '2020_05_28'),
#  ('DeerCreekTrail', '2020_06_04'),
#  ('DeerCreekTrail', '2020_06_13'),
#  ('EastRiverTrail', '2019_05_03'),
#  ('EastRiverTrail', '2019_05_08'),
#  ('EastRiverTrail', '2019_05_12'),
#  ('EastRiverTrail', '2019_05_19'),
#  ('EastRiverTrail', '2019_05_24'),
#  ('EastRiverTrail', '2019_05_30'),
#  ('EastRiverTrail', '2019_06_07'),
#  ('EastRiverTrail', '2020_05_01'),
#  ('EastRiverTrail', '2020_05_12'),
#  ('Elkton', '2019_06_06'),
#  ('Elkton', '2019_06_15'),
#  ('Elkton', '2019_06_20'),
#  ('Elkton', '2019_06_27'),
#  ('Elkton', '2019_07_03'),
#  ('Elkton', '2019_07_13'),
#  ('Elkton', '2019_07_19'),
#  ('Elkton', '2020_05_22'),
#  ('Elkton', '2020_05_29'),
#  ('Elkton', '2020_06_05'),
#  ('Elkton', '2020_06_12'),
#  ('JuddFalls', '2019_05_05'),
#  ('JuddFalls', '2019_05_12'),
#  ('JuddFalls', '2019_05_16'),
#  ('JuddFalls', '2019_05_26'),
#  ('JuddFalls', '2019_05_31'),
#  ('JuddFalls', '2019_06_05'),
#  ('JuddFalls', '2019_06_13'),
#  ('JuddFalls', '2020_04_08'),
#  ('JuddFalls', '2020_04_25'),
#  ('JuddFalls', '2020_05_06'),
#  ('JuddFalls', '2020_05_13'),
#  ('JuddFalls', '2020_05_21'),
#  ('LupineTrail', '2019_05_03'),
#  ('LupineTrail', '2019_05_08'),
#  ('LupineTrail', '2019_05_12'),
#  ('LupineTrail', '2019_05_15'),
#  ('LupineTrail', '2019_05_24'),
#  ('LupineTrail', '2019_05_30'),
#  ('LupineTrail', '2019_06_07'),
#  ('LupineTrail', '2020_04_14'),
#  ('LupineTrail', '2020_04_22'),
#  ('LupineTrail', '2020_04_30'),
#  ('LupineTrail', '2020_05_08'),
#  ('LupineTrail', '2020_05_14'),
#  ('LupineTrail', '2020_05_21'),
#  ('ParadiseBasin', '2019_06_29'),
#  ('ParadiseBasin', '2019_07_11'),
#  ('ParadiseBasin', '2019_07_18'),
#  ('ParadiseBasin', '2019_07_28'),
#  ('ParadiseBasin', '2019_08_19'),
#  ('ParadiseBasin', '2020_06_18'),
#  ('ParadiseBasin', '2020_06_25'),
#  ('ParadiseBasin', '2020_07_02'),
#  ('ParadiseBasin', '2020_07_09'),
#  ('ParadiseBasin', '2020_07_14'),
#  ('ParadiseBasin', '2020_07_21'),
#  ('RustlersGulch', '2019_06_02'),
#  ('RustlersGulch', '2019_06_09'),
#  ('RustlersGulch', '2019_06_16'),
#  ('RustlersGulch', '2019_06_24'),
#  ('RustlersGulch', '2019_07_01'),
#  ('RustlersGulch', '2020_05_20'),
#  ('RustlersGulch', '2020_05_27'),
#  ('RustlersGulch', '2020_06_03'),
#  ('SlideRockRoad', '2019_05_11'),
#  ('SlideRockRoad', '2019_05_19'),
#  ('SlideRockRoad', '2019_05_30'),
#  ('SlideRockRoad', '2019_06_06'),
#  ('SlideRockRoad', '2019_06_15'),
#  ('SlideRockRoad', '2020_04_30'),
#  ('SlideRockRoad', '2020_05_08'),
#  ('SlideRockRoad', '2020_05_14'),
#  ('SlideRockRoad', '2020_05_21'),
#  ('SnodgrassTrailhead', '2019_05_04'),
#  ('SnodgrassTrailhead', '2019_05_08'),
#  ('SnodgrassTrailhead', '2019_05_12'),
#  ('SnodgrassTrailhead', '2019_05_19'),
#  ('SnodgrassTrailhead', '2019_05_25'),
#  ('SnodgrassTrailhead', '2019_05_31'),
#  ('SnodgrassTrailhead', '2019_06_05'),
#  ('SnodgrassTrailhead', '2019_06_13'),
#  ('SnodgrassTrailhead', '2019_06_18'),
#  ('SnodgrassTrailhead', '2019_06_26'),
#  ('SnodgrassTrailhead', '2020_04_22'),
#  ('SnodgrassTrailhead', '2020_04_30'),
#  ('SnodgrassTrailhead', '2020_05_06'),
#  ('SnodgrassTrailhead', '2020_05_13'),
#  ('SnodgrassTrailhead', '2020_05_21'),
#  ('SnodgrassTrailhead', '2020_05_27'),
#  ('SnodgrassTrailhead', '2020_06_02'),
#  ('SnodgrassTrailhead', '2020_06_08'),
#  ('SouthBaldy', '2019_06_29'),
#  ('SouthBaldy', '2019_07_03'),
#  ('SouthBaldy', '2019_07_05'),
#  ('SouthBaldy', '2019_07_11'),
#  ('SouthBaldy', '2019_07_18'),
#  ('SouthBaldy', '2020_05_22'),
#  ('SouthBaldy', '2020_06_12')}

# %%
# loop through all files and remove completed ones

for file in tqdm(tif_files, unit='images'):
    filename = os.path.basename(file)
    tags = filename.split('_')
    location = tags[0]
    date = f'{tags[1]}_{tags[2]}_{tags[3]}'

    if (location, date) in completed_files:
        continue

    process_file(file)
# Out:
#   0%|          | 0/142 [00:00<?, ?images/s]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  82%|████████▏ | 117/142 [03:25<00:43,  1.75s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  83%|████████▎ | 118/142 [05:48<01:23,  3.46s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  84%|████████▍ | 119/142 [08:47<02:28,  6.44s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  85%|████████▍ | 120/142 [11:35<03:45, 10.24s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  85%|████████▌ | 121/142 [16:14<06:39, 19.01s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  86%|████████▌ | 122/142 [19:44<09:10, 27.53s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  87%|████████▋ | 124/142 [22:54<10:33, 35.17s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  88%|████████▊ | 125/142 [26:03<13:13, 46.67s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  89%|████████▊ | 126/142 [27:52<14:03, 52.70s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  89%|████████▉ | 127/142 [30:49<16:55, 67.71s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  90%|█████████ | 128/142 [33:30<18:59, 81.39s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  91%|█████████ | 129/142 [35:51<19:53, 91.84s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  92%|█████████▏| 130/142 [38:19<20:34, 102.91s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  95%|█████████▌| 135/142 [39:57<06:18, 54.08s/images] C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  96%|█████████▌| 136/142 [41:29<05:57, 59.55s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  97%|█████████▋| 138/142 [43:19<03:52, 58.13s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
#  98%|█████████▊| 139/142 [45:25<03:29, 69.84s/images]C:\Users\apfox\AppData\Local\Temp\ipykernel_27608\1344513471.py:27: RuntimeWarning: invalid value encountered in cast
#   return trimmed_snow_image.astype(np.uint8), resampled_snowbinary.astype(np.uint8), trimmed_snow_meta
# 100%|██████████| 142/142 [46:55<00:00, 19.82s/images]

# %%
# get list of all files in output directory ending in _images.npz
output_files = glob.glob(os.path.join(output_filepath, '*_images.npz'))
output_files
